# %%
import pandas as pd
import dask.dataframe as dd
from dask.multiprocessing import get

import itertools
pd.set_option('display.max_rows', 700)
pd.set_option('display.max_columns', 600)

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model, svm, tree
from sklearn.ensemble import RandomForestRegressor
from  sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.ensemble import RandomForestRegressor
import seaborn as sns
sns.set(rc={'figure.figsize':(16,9)})
#import swifter

np.random.seed(1907)

# %%
from tqdm import tqdm
# from tqdm.auto import tqdm  # for notebooks

#tqdm.pandas()

# %%
def initial_data_preparation():
    
    try:
        data = pd.read_csv("survey_results_public.csv")
        print("Data loaded locally.")
    except:
        data = pd.read_csv(r"https://raw.githubusercontent.com/ahmetsirel/ozu_data_science/master/DS%20555%20-%20Data%20Science%20%26%20Strategy/Project/survey_results_public.csv")
        print("Data loaded from github.")
    
    
    print(f"{len(data)} Rows.")

    # Numeric columns
    data[f"Age1stCode"] = data["Age1stCode"].replace('Younger than 5 years', "3").replace('Older than 85', "90").astype(float)
    data["YearsCode"] = data["YearsCode"].replace('Less than 1 year', "0.5").replace('More than 50 years', "55").astype(float)
    data["YearsCodePro"] = data["YearsCodePro"].replace('Less than 1 year', "0.5").replace('More than 50 years', "55").astype(float)

    # Drop unnecessary columns
    columns_to_drop = ["CurrencySymbol", "CompFreq", "CurrencyDesc", "CompTotal", "Respondent"]
    data = data.drop(columns_to_drop, axis=1)

    # Process multi choise columns
    def get_all_distinct_choices(column_name):
        list_of_choices = [str(item).split(";") for item in data[column_name].unique()]
        all_choices = []
        for ch in list_of_choices:
            all_choices += ch

        all_choices.remove("nan")
        all_choices = pd.Series(all_choices).unique().tolist()
        return all_choices

    def detect_multi_choise(column):
        return column.str.contains(";").sum() > 0

    is_multi_choice = data.loc[:, data.dtypes == "object"].apply(detect_multi_choise)
    multi_choice_columns = is_multi_choice[is_multi_choice].index.to_list()

    distinct_choice_lists_for_each_columns = {column: get_all_distinct_choices(column) for column in multi_choice_columns}

    def sep_multi_choice(row):
        #if int(row.name) % 5 ==0:
        #print(round((int(row.name) / len(data)),2))

        for column in multi_choice_columns:
            for choise in distinct_choice_lists_for_each_columns[column]:
                if type(row[column]) is str:
                    if  choise in row[column]:
                        row[column + "_" + choise] = 1
                    else:
                        row[column + "_" + choise] = 0
 
        return row

    try:
        data = pd.read_csv("data_prepared_temp_after_apply.csv")     
    except Exception as e:
        print(e)
        print("Multi choice columns processing is started.")
        #ddata = dd.from_pandas(data, npartitions=32)
        #data = ddata.map_partitions(lambda df: data.apply(sep_multi_choice, axis=1)).compute(get=get) 
        data = data.apply(sep_multi_choice, axis=1)
        print("Multi choice columns processed.")
    data = data.drop(multi_choice_columns, axis=1)
    
    
    # One hot encoding
    cat_columns = ["Country", "Gender", "JobSat", "JobSeek",
                                        "Employment",
                                        "MainBranch", 
                                        "Hobbyist", 
                                        "EdLevel", 
                                        "NEWDevOps", 
                                        "NEWDevOpsImpt", 
                                        "NEWEdImpt", 
                                        "NEWLearn",
                                        "NEWOffTopic",
                                        "NEWOnboardGood",
                                        "NEWOtherComms",
                                        "NEWOvertime",
                                        "NEWPurpleLink","OpSys","OrgSize",
                                        "PurchaseWhat","SOAccount",
                                        "SOComm","SOPartFreq","SOVisitFreq",
                                        "SurveyEase", "SurveyLength","Trans", "UndergradMajor","WelcomeChange"]
    cat_columns = [col for col in cat_columns if col not in multi_choice_columns]
    data = pd.get_dummies(data=data, columns=cat_columns)

    
    data = data.dropna(subset=["ConvertedComp"], axis=0)
    # Fill NaNs with mean
    nas = data.isna().sum()
    nas = nas[nas > 0]

    for na_col in nas.index:
        data[na_col].fillna(data[na_col].mean(), inplace=True)

    #LABEL :"ConvertedComp"
    return data

# %%
data = initial_data_preparation()
data.to_csv("data_prepared.csv",index=False)
# Out:
# Data loaded locally.
# 64461 Rows.

# %% [markdown]
# ## TODO
# - How many technologies he/she would like to learn? (DatabaseDesireNextYear, LanguageDesireNextYear) - Erdem
# - How many technologies was used in the past? (DatabaseWorkedWith, LanguageWorkedWith) - Erdem
# - Interaction between Job Satisfaction & Job Seeking columns and their impact on  compansation - Berk
# - New Job Hunt:Better Comp. & Job Seeking. - Berk
# - Target Encoding - Coutry, Tech, Currency  - Erdem

# %%
a = data[["ConvertedComp", "YearsCodePro", "Country_Turkey"]].sample(frac=1).reset_index(drop=True)
a = a[a["Country_Turkey"] == 1]
a = a[a.ConvertedComp <= 100000]
def year_div_10(row):
    row["YearsCodePro_"] = int(row["YearsCodePro"]/3)
    return row
sns.boxplot(x="YearsCodePro_", y="ConvertedComp", data=a.apply(year_div_10, axis=1))

# %%
a = data[["ConvertedComp", "EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)", "Country_Turkey"]].sample(frac=1).reset_index(drop=True)
a = a[a["Country_Turkey"] == 1]
a = a[a.ConvertedComp <= 100000]
a["ConvertedComp"] = a["ConvertedComp"] * 7.62
sns.boxplot(x="EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)", y="ConvertedComp", data=a)

# %%
a = data[["ConvertedComp", "EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)", "Country_Netherlands"]].sample(frac=1).reset_index(drop=True)
a = a[a["Country_Netherlands"] == 1]
a = a[a.ConvertedComp <= 500000]
sns.boxplot(x="EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)", y="ConvertedComp", data=a)

# %%
data[data["Country_Netherlands"] == 1]["EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.)"].value_counts()
# Out:
# 0    588
# 1    222
# Name: EdLevel_Master’s degree (M.A., M.S., M.Eng., MBA, etc.), dtype: int64

# %%
a = data[["ConvertedComp", "Age", "Country_Turkey"]].sample(frac=1).reset_index(drop=True)
a = a[a["Country_Turkey"] == 1]
a = a[a.ConvertedComp <= 100000]
def year_div_10(row):
    row["Age_"] = int(row["Age"] / 3)
    return row
sns.boxplot(x="Age_", y="ConvertedComp", data=a.apply(year_div_10, axis=1))

# %%
a[a["Country_Turkey"] == 1].Age.count()
# Out:
# 377

# %%
sns.swarmplot(x="DatabaseWorkedWith_Oracle", 
              y="ConvertedComp", 
              data=data[["DatabaseWorkedWith_Oracle", "ConvertedComp"]].sample(frac=1).reset_index(drop=True).head(2000),size=4)

# %%
data.head(3).T
# Out:
#                                                                7        9   \
# Age                                                     36.000000     22.0
# Age1stCode                                              12.000000     14.0
# ConvertedComp                                       116000.000000  32315.0
# DatabaseDesireNextYear_Cassandra                         0.000000      0.0
# DatabaseDesireNextYear_Couchbase                         0.000000      0.0
# DatabaseDesireNextYear_DynamoDB                          0.000000      0.0
# DatabaseDesireNextYear_Elasticsearch                     0.000000      0.0
# DatabaseDesireNextYear_Firebase                          0.000000      0.0
# DatabaseDesireNextYear_IBM DB2                           0.000000      0.0
# DatabaseDesireNextYear_MariaDB                           0.000000      0.0
# DatabaseDesireNextYear_Microsoft SQL Server              0.000000      1.0
# DatabaseDesireNextYear_MongoDB                           1.000000      0.0
# DatabaseDesireNextYear_MySQL                             0.000000      0.0
# DatabaseDesireNextYear_Oracle                            0.000000      0.0
# DatabaseDesireNextYear_PostgreSQL                        0.000000      0.0
# DatabaseDesireNextYear_Redis                             0.000000      0.0
# DatabaseDesireNextYear_SQLite                            0.000000      0.0
# DatabaseWorkedWith_Cassandra                             0.000000      0.0
# DatabaseWorkedWith_Couchbase                             0.000000      0.0
# DatabaseWorkedWith_DynamoDB                              0.000000      0.0
# DatabaseWorkedWith_Elasticsearch                         0.000000      0.0
# DatabaseWorkedWith_Firebase                              0.000000      0.0
# DatabaseWorkedWith_IBM DB2                               0.000000      0.0
# DatabaseWorkedWith_MariaDB                               1.000000      0.0
# DatabaseWorkedWith_Microsoft SQL Server                  0.000000      1.0
# DatabaseWorkedWith_MongoDB                               0.000000      0.0
# DatabaseWorkedWith_MySQL                                 1.000000      0.0
# DatabaseWorkedWith_Oracle                                0.000000      0.0
# DatabaseWorkedWith_PostgreSQL                            0.000000      0.0
# DatabaseWorkedWith_Redis                                 1.000000      0.0
# DatabaseWorkedWith_SQLite                                0.000000      0.0
# DevType_Academic researcher                              0.000000      0.0
# DevType_Data or business analyst                         0.000000      0.0
# DevType_Data scientist or machine learning spec...       0.000000      0.0
# DevType_Database administrator                           0.000000      1.0
# DevType_Designer                                         0.000000      0.0
# DevType_DevOps specialist                                0.000000      0.0
# DevType_Developer, QA or test                            0.000000      0.0
# DevType_Developer, back-end                              1.000000      0.0
# DevType_Developer, desktop or enterprise applic...       1.000000      0.0
# DevType_Developer, embedded applications or dev...       0.000000      0.0
# DevType_Developer, front-end                             0.000000      0.0
# DevType_Developer, full-stack                            0.000000      1.0
# DevType_Developer, game or graphics                      1.000000      0.0
# DevType_Developer, mobile                                0.000000      1.0
# DevType_Educator                                         0.000000      0.0
# DevType_Engineer, data                                   0.000000      0.0
# DevType_Engineer, site reliability                       0.000000      0.0
# DevType_Engineering manager                              0.000000      0.0
# DevType_Marketing or sales professional                  0.000000      0.0
# DevType_Product manager                                  0.000000      0.0
# DevType_Scientist                                        0.000000      0.0
# DevType_Senior executive/VP                              0.000000      0.0
# DevType_System administrator                             0.000000      0.0
# Ethnicity_Biracial                                       0.000000      0.0
# Ethnicity_Black or of African descent                    0.000000      0.0
# Ethnicity_East Asian                                     0.000000      0.0
# Ethnicity_Hispanic or Latino/a/x                         0.000000      0.0
# Ethnicity_Indigenous (such as Native American, ...       0.000000      0.0
# Ethnicity_Middle Eastern                                 0.000000      0.0
# Ethnicity_Multiracial                                    0.000000      0.0
# Ethnicity_South Asian                                    0.000000      0.0
# Ethnicity_Southeast Asian                                0.000000      0.0
# Ethnicity_White or of European descent                   1.000000      1.0
# Gender_Man                                               1.000000      1.0
# Gender_Non-binary, genderqueer, or gender non-c...       0.000000      0.0
# Gender_Woman                                             0.000000      0.0
# JobFactors_Diversity of the company or organiza...       0.000000      0.0
# JobFactors_Family friendliness                           1.000000      0.0
# JobFactors_Financial performance or funding sta...       0.000000      0.0
# JobFactors_Flex time or a flexible schedule              0.000000      1.0
# JobFactors_How widely used or impactful my work...       0.000000      1.0
# JobFactors_Industry that I’d be working in               0.000000      0.0
# JobFactors_Languages, frameworks, and other tec...       0.000000      0.0
# JobFactors_Office environment or company culture         0.000000      0.0
# JobFactors_Opportunities for professional devel...       1.000000      1.0
# JobFactors_Remote work options                           1.000000      0.0
# JobFactors_Specific department or team I’d be w...       0.000000      0.0
# LanguageDesireNextYear_Assembly                          0.000000      0.0
# LanguageDesireNextYear_Bash/Shell/PowerShell             0.000000      0.0
# LanguageDesireNextYear_C                                 0.000000      1.0
# LanguageDesireNextYear_C#                                0.000000      0.0
# LanguageDesireNextYear_C++                               0.000000      0.0
# LanguageDesireNextYear_Dart                              0.000000      0.0
# LanguageDesireNextYear_Go                                0.000000      0.0
# LanguageDesireNextYear_HTML/CSS                          0.000000      1.0
# LanguageDesireNextYear_Haskell                           0.000000      0.0
# LanguageDesireNextYear_Java                              1.000000      1.0
# LanguageDesireNextYear_JavaScript                        1.000000      1.0
# LanguageDesireNextYear_Julia                             0.000000      0.0
# LanguageDesireNextYear_Kotlin                            0.000000      0.0
# LanguageDesireNextYear_Objective-C                       0.000000      0.0
# LanguageDesireNextYear_PHP                               0.000000      0.0
# LanguageDesireNextYear_Perl                              0.000000      0.0
# LanguageDesireNextYear_Python                            0.000000      1.0
# LanguageDesireNextYear_R                                 0.000000      1.0
# LanguageDesireNextYear_Ruby                              0.000000      0.0
# LanguageDesireNextYear_Rust                              0.000000      0.0
# LanguageDesireNextYear_SQL                               0.000000      1.0
# LanguageDesireNextYear_Scala                             0.000000      0.0
# LanguageDesireNextYear_Swift                             0.000000      0.0
# LanguageDesireNextYear_TypeScript                        0.000000      0.0
# LanguageDesireNextYear_VBA                               0.000000      0.0
# LanguageWorkedWith_Assembly                              0.000000      0.0
# LanguageWorkedWith_Bash/Shell/PowerShell                 0.000000      0.0
# LanguageWorkedWith_C                                     0.000000      1.0
# LanguageWorkedWith_C#                                    0.000000      0.0
# LanguageWorkedWith_C++                                   0.000000      0.0
# LanguageWorkedWith_Dart                                  0.000000      0.0
# LanguageWorkedWith_Go                                    0.000000      0.0
# LanguageWorkedWith_HTML/CSS                              0.000000      1.0
# LanguageWorkedWith_Haskell                               0.000000      0.0
# LanguageWorkedWith_Java                                  0.000000      1.0
# LanguageWorkedWith_JavaScript                            0.000000      1.0
# LanguageWorkedWith_Julia                                 0.000000      0.0
# LanguageWorkedWith_Kotlin                                0.000000      0.0
# LanguageWorkedWith_Objective-C                           0.000000      0.0
# LanguageWorkedWith_PHP                                   0.000000      0.0
# LanguageWorkedWith_Perl                                  0.000000      0.0
# LanguageWorkedWith_Python                                1.000000      1.0
# LanguageWorkedWith_R                                     0.000000      0.0
# LanguageWorkedWith_Ruby                                  0.000000      0.0
# LanguageWorkedWith_Rust                                  0.000000      0.0
# LanguageWorkedWith_SQL                                   1.000000      1.0
# LanguageWorkedWith_Scala                                 0.000000      0.0
# LanguageWorkedWith_Swift                                 0.000000      0.0
# LanguageWorkedWith_TypeScript                            0.000000      0.0
# LanguageWorkedWith_VBA                                   0.000000      0.0
# MiscTechDesireNextYear_.NET                              0.000000      0.0
# MiscTechDesireNextYear_.NET Core                         0.000000      0.0
# MiscTechDesireNextYear_Ansible                           0.000000      0.0
# MiscTechDesireNextYear_Apache Spark                      0.000000      0.0
# MiscTechDesireNextYear_Chef                              0.000000      0.0
# MiscTechDesireNextYear_Cordova                           0.000000      0.0
# MiscTechDesireNextYear_Flutter                           0.000000      0.0
# MiscTechDesireNextYear_Hadoop                            0.000000      0.0
# MiscTechDesireNextYear_Keras                             0.000000      0.0
# MiscTechDesireNextYear_Node.js                           0.000000      0.0
# MiscTechDesireNextYear_Pandas                            0.000000      1.0
# MiscTechDesireNextYear_Puppet                            0.000000      0.0
# MiscTechDesireNextYear_React Native                      0.000000      0.0
# MiscTechDesireNextYear_TensorFlow                        0.000000      1.0
# MiscTechDesireNextYear_Teraform                          0.000000      0.0
# MiscTechDesireNextYear_Torch/PyTorch                     0.000000      0.0
# MiscTechDesireNextYear_Unity 3D                          1.000000      0.0
# MiscTechDesireNextYear_Unreal Engine                     0.000000      0.0
# MiscTechDesireNextYear_Xamarin                           0.000000      0.0
# MiscTechWorkedWith_.NET                                  0.000000      0.0
# MiscTechWorkedWith_.NET Core                             0.000000      0.0
# MiscTechWorkedWith_Ansible                               1.000000      0.0
# MiscTechWorkedWith_Apache Spark                          0.000000      0.0
# MiscTechWorkedWith_Chef                                  0.000000      0.0
# MiscTechWorkedWith_Cordova                               0.000000      0.0
# MiscTechWorkedWith_Flutter                               0.000000      0.0
# MiscTechWorkedWith_Hadoop                                0.000000      0.0
# MiscTechWorkedWith_Keras                                 0.000000      0.0
# MiscTechWorkedWith_Node.js                               0.000000      0.0
# MiscTechWorkedWith_Pandas                                0.000000      1.0
# MiscTechWorkedWith_Puppet                                0.000000      0.0
# MiscTechWorkedWith_React Native                          0.000000      0.0
# MiscTechWorkedWith_TensorFlow                            0.000000      0.0
# MiscTechWorkedWith_Teraform                              0.000000      0.0
# MiscTechWorkedWith_Torch/PyTorch                         0.000000      0.0
# MiscTechWorkedWith_Unity 3D                              0.000000      0.0
# MiscTechWorkedWith_Unreal Engine                         0.000000      0.0
# MiscTechWorkedWith_Xamarin                               0.000000      0.0
# NEWCollabToolsDesireNextYear_Confluence                  0.227433      0.0
# NEWCollabToolsDesireNextYear_Facebook Workplace          0.021894      0.0
# NEWCollabToolsDesireNextYear_Github                      0.770806      1.0
# NEWCollabToolsDesireNextYear_Gitlab                      0.367291      0.0
# NEWCollabToolsDesireNextYear_Google Suite (Docs...       0.349541      0.0
# NEWCollabToolsDesireNextYear_Jira                        0.383003      0.0
# NEWCollabToolsDesireNextYear_Microsoft Azure             0.174943      0.0
# NEWCollabToolsDesireNextYear_Microsoft Teams             0.189723      1.0
# NEWCollabToolsDesireNextYear_Slack                       0.504075      0.0
# NEWCollabToolsDesireNextYear_Stack Overflow for...       0.113820      0.0
# NEWCollabToolsDesireNextYear_Trello                      0.211513      0.0
# NEWCollabToolsWorkedWith_Confluence                      1.000000      0.0
# NEWCollabToolsWorkedWith_Facebook Workplace              0.000000      0.0
# NEWCollabToolsWorkedWith_Github                          1.000000      1.0
# NEWCollabToolsWorkedWith_Gitlab                          0.000000      0.0
# NEWCollabToolsWorkedWith_Google Suite (Docs, Me...       1.000000      0.0
# NEWCollabToolsWorkedWith_Jira                            1.000000      0.0
# NEWCollabToolsWorkedWith_Microsoft Azure                 0.000000      0.0
# NEWCollabToolsWorkedWith_Microsoft Teams                 1.000000      1.0
# NEWCollabToolsWorkedWith_Slack                           1.000000      0.0
# NEWCollabToolsWorkedWith_Stack Overflow for Teams        0.000000      0.0
# NEWCollabToolsWorkedWith_Trello                          0.000000      0.0
# NEWJobHuntResearch_Company reviews from third p...       1.000000      1.0
# NEWJobHuntResearch_Directly asking current or p...       0.000000      0.0
# NEWJobHuntResearch_Personal network - friends o...       1.000000      1.0
# NEWJobHuntResearch_Publicly available financial...       0.000000      1.0
# NEWJobHuntResearch_Read company media, such as ...       1.000000      0.0
# NEWJobHuntResearch_Read other media like news a...       1.000000      1.0
# NEWJobHunt_Better compensation                           1.000000      1.0
# NEWJobHunt_Better work/life balance                      1.000000      0.0
# NEWJobHunt_Curious about other opportunities             1.000000      1.0
# NEWJobHunt_Growth or leadership opportunities            1.000000      0.0
# NEWJobHunt_Having a bad day (or week or month) ...       0.000000      0.0
# NEWJobHunt_Just because                                  0.000000      0.0
# NEWJobHunt_Looking to relocate                           0.000000      1.0
# NEWJobHunt_Trouble with leadership at my company         1.000000      0.0
# NEWJobHunt_Trouble with my direct manager                1.000000      0.0
# NEWJobHunt_Trouble with my teammates                     0.000000      0.0
# NEWJobHunt_Wanting to share accomplishments wit...       0.000000      0.0
# NEWJobHunt_Wanting to work with new technologies         1.000000      0.0
# NEWPurchaseResearch_Ask developers I know/work ...       1.000000      1.0
# NEWPurchaseResearch_Read ratings or reviews on ...       1.000000      0.0
# NEWPurchaseResearch_Research companies that hav...       0.000000      0.0
# NEWPurchaseResearch_Research companies that hav...       0.000000      0.0
# NEWPurchaseResearch_Start a free trial                   1.000000      1.0
# NEWPurchaseResearch_Visit developer communities...       1.000000      1.0
# NEWSOSites_I have never visited any of these sites       0.000000      0.0
# NEWSOSites_Stack Exchange (public Q&A for a var...       0.000000      1.0
# NEWSOSites_Stack Overflow (public Q&A for anyon...       1.000000      1.0
# NEWSOSites_Stack Overflow Advertising (for tech...       0.000000      0.0
# NEWSOSites_Stack Overflow Jobs (for job seekers)         1.000000      0.0
# NEWSOSites_Stack Overflow Talent (for hiring co...       0.000000      0.0
# NEWSOSites_Stack Overflow for Teams (private Q&...       0.000000      0.0
# NEWStuck_Call a coworker or friend                       1.000000      0.0
# NEWStuck_Do other work and come back later               1.000000      0.0
# NEWStuck_Go for a walk or other physical activity        1.000000      0.0
# NEWStuck_Meditate                                        0.000000      0.0
# NEWStuck_Panic                                           0.000000      0.0
# NEWStuck_Play games                                      1.000000      0.0
# NEWStuck_Visit Stack Overflow                            1.000000      1.0
# NEWStuck_Visit another developer community (ple...       0.000000      0.0
# NEWStuck_Watch help / tutorial videos                    1.000000      0.0
# PlatformDesireNextYear_AWS                               0.000000      0.0
# PlatformDesireNextYear_Android                           0.000000      1.0
# PlatformDesireNextYear_Arduino                           0.000000      0.0
# PlatformDesireNextYear_Docker                            0.000000      0.0
# PlatformDesireNextYear_Google Cloud Platform             0.000000      0.0
# PlatformDesireNextYear_Heroku                            0.000000      0.0
# PlatformDesireNextYear_IBM Cloud or Watson               0.000000      0.0
# PlatformDesireNextYear_Kubernetes                        0.000000      0.0
# PlatformDesireNextYear_Linux                             0.000000      1.0
# PlatformDesireNextYear_MacOS                             0.000000      0.0
# PlatformDesireNextYear_Microsoft Azure                   0.000000      0.0
# PlatformDesireNextYear_Raspberry Pi                      0.000000      1.0
# PlatformDesireNextYear_Slack Apps and Integrations       1.000000      0.0
# PlatformDesireNextYear_Windows                           0.000000      1.0
# PlatformDesireNextYear_WordPress                         0.000000      0.0
# PlatformDesireNextYear_iOS                               1.000000      0.0
# PlatformWorkedWith_AWS                                   0.000000      0.0
# PlatformWorkedWith_Android                               0.000000      1.0
# PlatformWorkedWith_Arduino                               0.000000      0.0
# PlatformWorkedWith_Docker                                1.000000      0.0
# PlatformWorkedWith_Google Cloud Platform                 0.000000      0.0
# PlatformWorkedWith_Heroku                                0.000000      0.0
# PlatformWorkedWith_IBM Cloud or Watson                   0.000000      0.0
# PlatformWorkedWith_Kubernetes                            0.000000      0.0
# PlatformWorkedWith_Linux                                 0.000000      1.0
# PlatformWorkedWith_MacOS                                 0.000000      0.0
# PlatformWorkedWith_Microsoft Azure                       0.000000      0.0
# PlatformWorkedWith_Raspberry Pi                          0.000000      1.0
# PlatformWorkedWith_Slack Apps and Integrations           0.000000      0.0
# PlatformWorkedWith_Windows                               0.000000      1.0
# PlatformWorkedWith_WordPress                             0.000000      0.0
# PlatformWorkedWith_iOS                                   0.000000      0.0
# Sexuality_Bisexual                                       0.000000      0.0
# Sexuality_Gay or Lesbian                                 0.000000      0.0
# Sexuality_Queer                                          0.000000      0.0
# Sexuality_Straight / Heterosexual                        1.000000      1.0
# WebframeDesireNextYear_ASP.NET                           0.000000      0.0
# WebframeDesireNextYear_ASP.NET Core                      0.000000      0.0
# WebframeDesireNextYear_Angular                           0.000000      0.0
# WebframeDesireNextYear_Angular.js                        0.000000      0.0
# WebframeDesireNextYear_Django                            1.000000      0.0
# WebframeDesireNextYear_Drupal                            0.000000      0.0
# WebframeDesireNextYear_Express                           0.000000      0.0
# WebframeDesireNextYear_Flask                             0.000000      1.0
# WebframeDesireNextYear_Gatsby                            0.000000      0.0
# WebframeDesireNextYear_Laravel                           0.000000      0.0
# WebframeDesireNextYear_React.js                          1.000000      0.0
# WebframeDesireNextYear_Ruby on Rails                     0.000000      0.0
# WebframeDesireNextYear_Spring                            0.000000      0.0
# WebframeDesireNextYear_Symfony                           0.000000      0.0
# WebframeDesireNextYear_Vue.js                            1.000000      0.0
# WebframeDesireNextYear_jQuery                            0.000000      1.0
# WebframeWorkedWith_ASP.NET                               0.000000      0.0
# WebframeWorkedWith_ASP.NET Core                          0.000000      0.0
# WebframeWorkedWith_Angular                               0.000000      0.0
# WebframeWorkedWith_Angular.js                            0.000000      0.0
# WebframeWorkedWith_Django                                0.000000      0.0
# WebframeWorkedWith_Drupal                                0.000000      0.0
# WebframeWorkedWith_Express                               0.000000      0.0
# WebframeWorkedWith_Flask                                 1.000000      1.0
# WebframeWorkedWith_Gatsby                                0.000000      0.0
# WebframeWorkedWith_Laravel                               0.000000      0.0
# WebframeWorkedWith_React.js                              0.000000      0.0
# WebframeWorkedWith_Ruby on Rails                         0.000000      0.0
# WebframeWorkedWith_Spring                                0.000000      0.0
# WebframeWorkedWith_Symfony                               0.000000      0.0
# WebframeWorkedWith_Vue.js                                0.000000      0.0
# WebframeWorkedWith_jQuery                                0.000000      1.0
# WorkWeekHrs                                             39.000000     36.0
# YearsCode                                               17.000000      8.0
# YearsCodePro                                            13.000000      4.0
# Country_Afghanistan                                      0.000000      0.0
# Country_Albania                                          0.000000      0.0
# Country_Algeria                                          0.000000      0.0
# Country_Andorra                                          0.000000      0.0
# Country_Angola                                           0.000000      0.0
# Country_Antigua and Barbuda                              0.000000      0.0
# Country_Argentina                                        0.000000      0.0
# Country_Armenia                                          0.000000      0.0
# Country_Australia                                        0.000000      0.0
# Country_Austria                                          0.000000      0.0
# Country_Azerbaijan                                       0.000000      0.0
# Country_Bahamas                                          0.000000      0.0
# Country_Bahrain                                          0.000000      0.0
# Country_Bangladesh                                       0.000000      0.0
# Country_Barbados                                         0.000000      0.0
# Country_Belarus                                          0.000000      0.0
# Country_Belgium                                          0.000000      0.0
# Country_Belize                                           0.000000      0.0
# Country_Benin                                            0.000000      0.0
# Country_Bhutan                                           0.000000      0.0
# Country_Bolivia                                          0.000000      0.0
# Country_Bosnia and Herzegovina                           0.000000      0.0
# Country_Botswana                                         0.000000      0.0
# Country_Brazil                                           0.000000      0.0
# Country_Brunei Darussalam                                0.000000      0.0
# Country_Bulgaria                                         0.000000      0.0
# Country_Burkina Faso                                     0.000000      0.0
# Country_Burundi                                          0.000000      0.0
# Country_Cambodia                                         0.000000      0.0
# Country_Cameroon                                         0.000000      0.0
# Country_Canada                                           0.000000      0.0
# Country_Cape Verde                                       0.000000      0.0
# Country_Chad                                             0.000000      0.0
# Country_Chile                                            0.000000      0.0
# Country_China                                            0.000000      0.0
# Country_Colombia                                         0.000000      0.0
# Country_Congo, Republic of the...                        0.000000      0.0
# Country_Costa Rica                                       0.000000      0.0
# Country_Croatia                                          0.000000      0.0
# Country_Cuba                                             0.000000      0.0
# Country_Cyprus                                           0.000000      0.0
# Country_Czech Republic                                   0.000000      0.0
# Country_Côte d'Ivoire                                    0.000000      0.0
# Country_Democratic Republic of the Congo                 0.000000      0.0
# Country_Denmark                                          0.000000      0.0
# Country_Djibouti                                         0.000000      0.0
# Country_Dominican Republic                               0.000000      0.0
# Country_Ecuador                                          0.000000      0.0
# Country_Egypt                                            0.000000      0.0
# Country_El Salvador                                      0.000000      0.0
# Country_Eritrea                                          0.000000      0.0
# Country_Estonia                                          0.000000      0.0
# Country_Ethiopia                                         0.000000      0.0
# Country_Fiji                                             0.000000      0.0
# Country_Finland                                          0.000000      0.0
# Country_France                                           0.000000      0.0
# Country_Gabon                                            0.000000      0.0
# Country_Gambia                                           0.000000      0.0
# Country_Georgia                                          0.000000      0.0
# Country_Germany                                          0.000000      0.0
# Country_Ghana                                            0.000000      0.0
# Country_Greece                                           0.000000      0.0
# Country_Grenada                                          0.000000      0.0
# Country_Guatemala                                        0.000000      0.0
# Country_Guinea                                           0.000000      0.0
# Country_Guyana                                           0.000000      0.0
# Country_Haiti                                            0.000000      0.0
# Country_Honduras                                         0.000000      0.0
# Country_Hong Kong (S.A.R.)                               0.000000      0.0
# Country_Hungary                                          0.000000      0.0
# Country_Iceland                                          0.000000      0.0
# Country_India                                            0.000000      0.0
# Country_Indonesia                                        0.000000      0.0
# Country_Iran                                             0.000000      0.0
# Country_Iraq                                             0.000000      0.0
# Country_Ireland                                          0.000000      0.0
# Country_Isle of Man                                      0.000000      0.0
# Country_Israel                                           0.000000      0.0
# Country_Italy                                            0.000000      0.0
# Country_Jamaica                                          0.000000      0.0
# Country_Japan                                            0.000000      0.0
# Country_Jordan                                           0.000000      0.0
# Country_Kazakhstan                                       0.000000      0.0
# Country_Kenya                                            0.000000      0.0
# Country_Kiribati                                         0.000000      0.0
# Country_Kosovo                                           0.000000      0.0
# Country_Kuwait                                           0.000000      0.0
# Country_Kyrgyzstan                                       0.000000      0.0
# Country_Lao People's Democratic Republic                 0.000000      0.0
# Country_Latvia                                           0.000000      0.0
# Country_Lebanon                                          0.000000      0.0
# Country_Lesotho                                          0.000000      0.0
# Country_Libyan Arab Jamahiriya                           0.000000      0.0
# Country_Liechtenstein                                    0.000000      0.0
# Country_Lithuania                                        0.000000      0.0
# Country_Luxembourg                                       0.000000      0.0
# Country_Madagascar                                       0.000000      0.0
# Country_Malawi                                           0.000000      0.0
# Country_Malaysia                                         0.000000      0.0
# Country_Maldives                                         0.000000      0.0
# Country_Mali                                             0.000000      0.0
# Country_Malta                                            0.000000      0.0
# Country_Marshall Islands                                 0.000000      0.0
# Country_Mauritania                                       0.000000      0.0
# Country_Mauritius                                        0.000000      0.0
# Country_Mexico                                           0.000000      0.0
# Country_Micronesia, Federated States of...               0.000000      0.0
# Country_Monaco                                           0.000000      0.0
# Country_Mongolia                                         0.000000      0.0
# Country_Montenegro                                       0.000000      0.0
# Country_Morocco                                          0.000000      0.0
# Country_Mozambique                                       0.000000      0.0
# Country_Myanmar                                          0.000000      0.0
# Country_Namibia                                          0.000000      0.0
# Country_Nauru                                            0.000000      0.0
# Country_Nepal                                            0.000000      0.0
# Country_Netherlands                                      0.000000      0.0
# Country_New Zealand                                      0.000000      0.0
# Country_Nicaragua                                        0.000000      0.0
# Country_Niger                                            0.000000      0.0
# Country_Nigeria                                          0.000000      0.0
# Country_Nomadic                                          0.000000      0.0
# Country_North Korea                                      0.000000      0.0
# Country_Norway                                           0.000000      0.0
# Country_Oman                                             0.000000      0.0
# Country_Pakistan                                         0.000000      0.0
# Country_Panama                                           0.000000      0.0
# Country_Papua New Guinea                                 0.000000      0.0
# Country_Paraguay                                         0.000000      0.0
# Country_Peru                                             0.000000      0.0
# Country_Philippines                                      0.000000      0.0
# Country_Poland                                           0.000000      0.0
# Country_Portugal                                         0.000000      0.0
# Country_Qatar                                            0.000000      0.0
# Country_Republic of Korea                                0.000000      0.0
# Country_Republic of Moldova                              0.000000      0.0
# Country_Romania                                          0.000000      0.0
# Country_Russian Federation                               0.000000      0.0
# Country_Rwanda                                           0.000000      0.0
# Country_Saint Lucia                                      0.000000      0.0
# Country_Saint Vincent and the Grenadines                 0.000000      0.0
# Country_San Marino                                       0.000000      0.0
# Country_Saudi Arabia                                     0.000000      0.0
# Country_Senegal                                          0.000000      0.0
# Country_Serbia                                           0.000000      0.0
# Country_Sierra Leone                                     0.000000      0.0
# Country_Singapore                                        0.000000      0.0
# Country_Slovakia                                         0.000000      0.0
# Country_Slovenia                                         0.000000      0.0
# Country_Solomon Islands                                  0.000000      0.0
# Country_Somalia                                          0.000000      0.0
# Country_South Africa                                     0.000000      0.0
# Country_South Korea                                      0.000000      0.0
# Country_Spain                                            0.000000      0.0
# Country_Sri Lanka                                        0.000000      0.0
# Country_Sudan                                            0.000000      0.0
# Country_Swaziland                                        0.000000      0.0
# Country_Sweden                                           0.000000      0.0
# Country_Switzerland                                      0.000000      0.0
# Country_Syrian Arab Republic                             0.000000      0.0
# Country_Taiwan                                           0.000000      0.0
# Country_Tajikistan                                       0.000000      0.0
# Country_Thailand                                         0.000000      0.0
# Country_The former Yugoslav Republic of Macedonia        0.000000      0.0
# Country_Timor-Leste                                      0.000000      0.0
# Country_Togo                                             0.000000      0.0
# Country_Trinidad and Tobago                              0.000000      0.0
# Country_Tunisia                                          0.000000      0.0
# Country_Turkey                                           0.000000      0.0
# Country_Turkmenistan                                     0.000000      0.0
# Country_Uganda                                           0.000000      0.0
# Country_Ukraine                                          0.000000      0.0
# Country_United Arab Emirates                             0.000000      0.0
# Country_United Kingdom                                   0.000000      1.0
# Country_United Republic of Tanzania                      0.000000      0.0
# Country_United States                                    1.000000      0.0
# Country_Uruguay                                          0.000000      0.0
# Country_Uzbekistan                                       0.000000      0.0
# Country_Venezuela, Bolivarian Republic of...             0.000000      0.0
# Country_Viet Nam                                         0.000000      0.0
# Country_Yemen                                            0.000000      0.0
# Country_Zambia                                           0.000000      0.0
# Country_Zimbabwe                                         0.000000      0.0
# JobSat_Neither satisfied nor dissatisfied                0.000000      0.0
# JobSat_Slightly dissatisfied                             1.000000      0.0
# JobSat_Slightly satisfied                                0.000000      0.0
# JobSat_Very dissatisfied                                 0.000000      0.0
# JobSat_Very satisfied                                    0.000000      1.0
# JobSeek_I am actively looking for a job                  0.000000      0.0
# JobSeek_I am not interested in new job opportun...       0.000000      0.0
# JobSeek_I’m not actively looking, but I am open...       1.000000      1.0
# Employment_Employed full-time                            1.000000      1.0
# Employment_Employed part-time                            0.000000      0.0
# Employment_Independent contractor, freelancer, ...       0.000000      0.0
# Employment_Not employed, and not looking for work        0.000000      0.0
# Employment_Not employed, but looking for work            0.000000      0.0
# Employment_Retired                                       0.000000      0.0
# Employment_Student                                       0.000000      0.0
# MainBranch_I am a developer by profession                1.000000      1.0
# MainBranch_I am a student who is learning to code        0.000000      0.0
# MainBranch_I am not primarily a developer, but ...       0.000000      0.0
# MainBranch_I code primarily as a hobby                   0.000000      0.0
# MainBranch_I used to be a developer by professi...       0.000000      0.0
# Hobbyist_No                                              0.000000      0.0
# Hobbyist_Yes                                             1.000000      1.0
# EdLevel_Associate degree (A.A., A.S., etc.)              0.000000      0.0
# EdLevel_Bachelor’s degree (B.A., B.S., B.Eng., ...       1.000000      0.0
# EdLevel_I never completed any formal education           0.000000      0.0
# EdLevel_Master’s degree (M.A., M.S., M.Eng., MB...       0.000000      1.0
# EdLevel_Other doctoral degree (Ph.D., Ed.D., etc.)       0.000000      0.0
# EdLevel_Primary/elementary school                        0.000000      0.0
# EdLevel_Professional degree (JD, MD, etc.)               0.000000      0.0
# EdLevel_Secondary school (e.g. American high sc...       0.000000      0.0
# EdLevel_Some college/university study without e...       0.000000      0.0
# NEWDevOps_No                                             0.000000      1.0
# NEWDevOps_Not sure                                       0.000000      0.0
# NEWDevOps_Yes                                            1.000000      0.0
# NEWDevOpsImpt_Extremely important                        1.000000      0.0
# NEWDevOpsImpt_Neutral                                    0.000000      1.0
# NEWDevOpsImpt_Not at all important                       0.000000      0.0
# NEWDevOpsImpt_Not very important                         0.000000      0.0
# NEWDevOpsImpt_Somewhat important                         0.000000      0.0
# NEWEdImpt_Critically important                           0.000000      0.0
# NEWEdImpt_Fairly important                               0.000000      1.0
# NEWEdImpt_Not at all important/not necessary             1.000000      0.0
# NEWEdImpt_Somewhat important                             0.000000      0.0
# NEWEdImpt_Very important                                 0.000000      0.0
# NEWLearn_Every few months                                0.000000      1.0
# NEWLearn_Once a decade                                   0.000000      0.0
# NEWLearn_Once a year                                     1.000000      0.0
# NEWLearn_Once every few years                            0.000000      0.0
# NEWOffTopic_No                                           0.000000      0.0
# NEWOffTopic_Not sure                                     1.000000      0.0
# NEWOffTopic_Yes                                          0.000000      1.0
# NEWOnboardGood_No                                        0.000000      0.0
# NEWOnboardGood_Onboarding? What onboarding?              0.000000      1.0
# NEWOnboardGood_Yes                                       1.000000      0.0
# NEWOtherComms_No                                         1.000000      1.0
# NEWOtherComms_Yes                                        0.000000      0.0
# NEWOvertime_Never                                        0.000000      0.0
# NEWOvertime_Occasionally: 1-2 days per quarter ...       1.000000      0.0
# NEWOvertime_Often: 1-2 days per week or more             0.000000      1.0
# NEWOvertime_Rarely: 1-2 days per year or less            0.000000      0.0
# NEWOvertime_Sometimes: 1-2 days per month but l...       0.000000      0.0
# NEWPurpleLink_Amused                                     0.000000      0.0
# NEWPurpleLink_Annoyed                                    0.000000      0.0
# NEWPurpleLink_Hello, old friend                          1.000000      1.0
# NEWPurpleLink_Indifferent                                0.000000      0.0
# OpSys_BSD                                                0.000000      0.0
# OpSys_Linux-based                                        1.000000      0.0
# OpSys_MacOS                                              0.000000      0.0
# OpSys_Windows                                            0.000000      1.0
# OrgSize_1,000 to 4,999 employees                         0.000000      0.0
# OrgSize_10 to 19 employees                               0.000000      0.0
# OrgSize_10,000 or more employees                         0.000000      0.0
# OrgSize_100 to 499 employees                             0.000000      0.0
# OrgSize_2 to 9 employees                                 0.000000      1.0
# OrgSize_20 to 99 employees                               1.000000      0.0
# OrgSize_5,000 to 9,999 employees                         0.000000      0.0
# OrgSize_500 to 999 employees                             0.000000      0.0
# OrgSize_Just me - I am a freelancer, sole propr...       0.000000      0.0
# PurchaseWhat_I have a great deal of influence            0.000000      1.0
# PurchaseWhat_I have little or no influence               0.000000      0.0
# PurchaseWhat_I have some influence                       1.000000      0.0
# SOAccount_No                                             0.000000      0.0
# SOAccount_Not sure/can't remember                        0.000000      0.0
# SOAccount_Yes                                            1.000000      1.0
# SOComm_Neutral                                           0.000000      0.0
# SOComm_No, not at all                                    0.000000      0.0
# SOComm_No, not really                                    1.000000      0.0
# SOComm_Not sure                                          0.000000      0.0
# SOComm_Yes, definitely                                   0.000000      1.0
# SOComm_Yes, somewhat                                     0.000000      0.0
# SOPartFreq_A few times per month or weekly               0.000000      0.0
# SOPartFreq_A few times per week                          0.000000      0.0
# SOPartFreq_Daily or almost daily                         0.000000      0.0
# SOPartFreq_I have never participated in Q&A on ...       0.000000      0.0
# SOPartFreq_Less than once per month or monthly           1.000000      0.0
# SOPartFreq_Multiple times per day                        0.000000      1.0
# SOVisitFreq_A few times per month or weekly              0.000000      0.0
# SOVisitFreq_A few times per week                         0.000000      0.0
# SOVisitFreq_Daily or almost daily                        0.000000      0.0
# SOVisitFreq_I have never visited Stack Overflow...       0.000000      0.0
# SOVisitFreq_Less than once per month or monthly          0.000000      0.0
# SOVisitFreq_Multiple times per day                       1.000000      1.0
# SurveyEase_Difficult                                     0.000000      0.0
# SurveyEase_Easy                                          1.000000      1.0
# SurveyEase_Neither easy nor difficult                    0.000000      0.0
# SurveyLength_Appropriate in length                       1.000000      1.0
# SurveyLength_Too long                                    0.000000      0.0
# SurveyLength_Too short                                   0.000000      0.0
# Trans_No                                                 1.000000      1.0
# Trans_Yes                                                0.000000      0.0
# UndergradMajor_A business discipline (such as a...       0.000000      0.0
# UndergradMajor_A health science (such as nursin...       0.000000      0.0
# UndergradMajor_A humanities discipline (such as...       0.000000      0.0
# UndergradMajor_A natural science (such as biolo...       0.000000      0.0
# UndergradMajor_A social science (such as anthro...       0.000000      0.0
# UndergradMajor_Another engineering discipline (...       0.000000      0.0
# UndergradMajor_Computer science, computer engin...       1.000000      0.0
# UndergradMajor_Fine arts or performing arts (su...       0.000000      0.0
# UndergradMajor_I never declared a major                  0.000000      0.0
# UndergradMajor_Information systems, information...       0.000000      0.0
# UndergradMajor_Mathematics or statistics                 0.000000      1.0
# UndergradMajor_Web development or web design             0.000000      0.0
# WelcomeChange_A lot less welcome now than last ...       0.000000      0.0
# WelcomeChange_A lot more welcome now than last ...       0.000000      0.0
# WelcomeChange_Just as welcome now as I felt las...       1.000000      0.0
# WelcomeChange_Not applicable - I did not use St...       0.000000      0.0
# WelcomeChange_Somewhat less welcome now than la...       0.000000      0.0
# WelcomeChange_Somewhat more welcome now than la...       0.000000      1.0
#
#                                                               10
# Age                                                    23.000000
# Age1stCode                                             13.000000
# ConvertedComp                                       40070.000000
# DatabaseDesireNextYear_Cassandra                        0.000000
# ...
# Country_Iran                                            0.000000
# Country_Iraq                                            0.000000
# Country_Ireland                                         0.000000
# Country_Isle of Man                                     0.000000
# Country_Israel                                          0.000000
# Country_Italy                                           0.000000
# Country_Jamaica                                         0.000000
# Country_Japan                                           0.000000
# Country_Jordan                                          0.000000
# Country_Kazakhstan                                      0.000000
# Country_Kenya                                           0.000000
# Country_Kiribati                                        0.000000
# Country_Kosovo                                          0.000000
# Country_Kuwait                                          0.000000
# Country_Kyrgyzstan                                      0.000000
# Country_Lao People's Democratic Republic                0.000000
# Country_Latvia                                          0.000000
# Country_Lebanon                                         0.000000
# Country_Lesotho                                         0.000000
# Country_Libyan Arab Jamahiriya                          0.000000
# Country_Liechtenstein                                   0.000000
# Country_Lithuania                                       0.000000
# Country_Luxembourg                                      0.000000
# Country_Madagascar                                      0.000000
# Country_Malawi                                          0.000000
# Country_Malaysia                                        0.000000
# Country_Maldives                                        0.000000
# Country_Mali                                            0.000000
# Country_Malta                                           0.000000
# Country_Marshall Islands                                0.000000
# Country_Mauritania                                      0.000000
# Country_Mauritius                                       0.000000
# Country_Mexico                                          0.000000
# Country_Micronesia, Federated States of...              0.000000
# Country_Monaco                                          0.000000
# Country_Mongolia                                        0.000000
# Country_Montenegro                                      0.000000
# Country_Morocco                                         0.000000
# Country_Mozambique                                      0.000000
# Country_Myanmar                                         0.000000
# Country_Namibia                                         0.000000
# Country_Nauru                                           0.000000
# Country_Nepal                                           0.000000
# Country_Netherlands                                     0.000000
# Country_New Zealand                                     0.000000
# Country_Nicaragua                                       0.000000
# Country_Niger                                           0.000000
# Country_Nigeria                                         0.000000
# Country_Nomadic                                         0.000000
# Country_North Korea                                     0.000000
# Country_Norway                                          0.000000
# Country_Oman                                            0.000000
# Country_Pakistan                                        0.000000
# Country_Panama                                          0.000000
# Country_Papua New Guinea                                0.000000
# Country_Paraguay                                        0.000000
# Country_Peru                                            0.000000
# Country_Philippines                                     0.000000
# Country_Poland                                          0.000000
# Country_Portugal                                        0.000000
# Country_Qatar                                           0.000000
# Country_Republic of Korea                               0.000000
# Country_Republic of Moldova                             0.000000
# Country_Romania                                         0.000000
# Country_Russian Federation                              0.000000
# Country_Rwanda                                          0.000000
# Country_Saint Lucia                                     0.000000
# Country_Saint Vincent and the Grenadines                0.000000
# Country_San Marino                                      0.000000
# Country_Saudi Arabia                                    0.000000
# Country_Senegal                                         0.000000
# Country_Serbia                                          0.000000
# Country_Sierra Leone                                    0.000000
# Country_Singapore                                       0.000000
# Country_Slovakia                                        0.000000
# Country_Slovenia                                        0.000000
# Country_Solomon Islands                                 0.000000
# Country_Somalia                                         0.000000
# Country_South Africa                                    0.000000
# Country_South Korea                                     0.000000
# Country_Spain                                           0.000000
# Country_Sri Lanka                                       0.000000
# Country_Sudan                                           0.000000
# Country_Swaziland                                       0.000000
# Country_Sweden                                          0.000000
# Country_Switzerland                                     0.000000
# Country_Syrian Arab Republic                            0.000000
# Country_Taiwan                                          0.000000
# Country_Tajikistan                                      0.000000
# Country_Thailand                                        0.000000
# Country_The former Yugoslav Republic of Macedonia       0.000000
# Country_Timor-Leste                                     0.000000
# Country_Togo                                            0.000000
# Country_Trinidad and Tobago                             0.000000
# Country_Tunisia                                         0.000000
# Country_Turkey                                          0.000000
# Country_Turkmenistan                                    0.000000
# Country_Uganda                                          0.000000
# Country_Ukraine                                         0.000000
# Country_United Arab Emirates                            0.000000
# Country_United Kingdom                                  1.000000
# Country_United Republic of Tanzania                     0.000000
# Country_United States                                   0.000000
# Country_Uruguay                                         0.000000
# Country_Uzbekistan                                      0.000000
# Country_Venezuela, Bolivarian Republic of...            0.000000
# Country_Viet Nam                                        0.000000
# Country_Yemen                                           0.000000
# Country_Zambia                                          0.000000
# Country_Zimbabwe                                        0.000000
# JobSat_Neither satisfied nor dissatisfied               0.000000
# JobSat_Slightly dissatisfied                            1.000000
# JobSat_Slightly satisfied                               0.000000
# JobSat_Very dissatisfied                                0.000000
# JobSat_Very satisfied                                   0.000000
# JobSeek_I am actively looking for a job                 1.000000
# JobSeek_I am not interested in new job opportun...      0.000000
# JobSeek_I’m not actively looking, but I am open...      0.000000
# Employment_Employed full-time                           1.000000
# Employment_Employed part-time                           0.000000
# Employment_Independent contractor, freelancer, ...      0.000000
# Employment_Not employed, and not looking for work       0.000000
# Employment_Not employed, but looking for work           0.000000
# Employment_Retired                                      0.000000
# Employment_Student                                      0.000000
# MainBranch_I am a developer by profession               1.000000
# MainBranch_I am a student who is learning to code       0.000000
# MainBranch_I am not primarily a developer, but ...      0.000000
# MainBranch_I code primarily as a hobby                  0.000000
# MainBranch_I used to be a developer by professi...      0.000000
# Hobbyist_No                                             0.000000
# Hobbyist_Yes                                            1.000000
# EdLevel_Associate degree (A.A., A.S., etc.)             0.000000
# EdLevel_Bachelor’s degree (B.A., B.S., B.Eng., ...      1.000000
# EdLevel_I never completed any formal education          0.000000
# EdLevel_Master’s degree (M.A., M.S., M.Eng., MB...      0.000000
# EdLevel_Other doctoral degree (Ph.D., Ed.D., etc.)      0.000000
# EdLevel_Primary/elementary school                       0.000000
# EdLevel_Professional degree (JD, MD, etc.)              0.000000
# EdLevel_Secondary school (e.g. American high sc...      0.000000
# EdLevel_Some college/university study without e...      0.000000
# NEWDevOps_No                                            1.000000
# NEWDevOps_Not sure                                      0.000000
# NEWDevOps_Yes                                           0.000000
# NEWDevOpsImpt_Extremely important                       1.000000
# NEWDevOpsImpt_Neutral                                   0.000000
# NEWDevOpsImpt_Not at all important                      0.000000
# NEWDevOpsImpt_Not very important                        0.000000
# NEWDevOpsImpt_Somewhat important                        0.000000
# NEWEdImpt_Critically important                          0.000000
# NEWEdImpt_Fairly important                              0.000000
# NEWEdImpt_Not at all important/not necessary            0.000000
# NEWEdImpt_Somewhat important                            0.000000
# NEWEdImpt_Very important                                1.000000
# NEWLearn_Every few months                               1.000000
# NEWLearn_Once a decade                                  0.000000
# NEWLearn_Once a year                                    0.000000
# NEWLearn_Once every few years                           0.000000
# NEWOffTopic_No                                          1.000000
# NEWOffTopic_Not sure                                    0.000000
# NEWOffTopic_Yes                                         0.000000
# NEWOnboardGood_No                                       0.000000
# NEWOnboardGood_Onboarding? What onboarding?             0.000000
# NEWOnboardGood_Yes                                      1.000000
# NEWOtherComms_No                                        1.000000
# NEWOtherComms_Yes                                       0.000000
# NEWOvertime_Never                                       0.000000
# NEWOvertime_Occasionally: 1-2 days per quarter ...      0.000000
# NEWOvertime_Often: 1-2 days per week or more            0.000000
# NEWOvertime_Rarely: 1-2 days per year or less           1.000000
# NEWOvertime_Sometimes: 1-2 days per month but l...      0.000000
# NEWPurpleLink_Amused                                    0.000000
# NEWPurpleLink_Annoyed                                   1.000000
# NEWPurpleLink_Hello, old friend                         0.000000
# NEWPurpleLink_Indifferent                               0.000000
# OpSys_BSD                                               0.000000
# OpSys_Linux-based                                       0.000000
# OpSys_MacOS                                             0.000000
# OpSys_Windows                                           1.000000
# OrgSize_1,000 to 4,999 employees                        0.000000
# OrgSize_10 to 19 employees                              0.000000
# OrgSize_10,000 or more employees                        1.000000
# OrgSize_100 to 499 employees                            0.000000
# OrgSize_2 to 9 employees                                0.000000
# OrgSize_20 to 99 employees                              0.000000
# OrgSize_5,000 to 9,999 employees                        0.000000
# OrgSize_500 to 999 employees                            0.000000
# OrgSize_Just me - I am a freelancer, sole propr...      0.000000
# PurchaseWhat_I have a great deal of influence           0.000000
# PurchaseWhat_I have little or no influence              1.000000
# PurchaseWhat_I have some influence                      0.000000
# SOAccount_No                                            0.000000
# SOAccount_Not sure/can't remember                       0.000000
# SOAccount_Yes                                           1.000000
# SOComm_Neutral                                          0.000000
# SOComm_No, not at all                                   0.000000
# SOComm_No, not really                                   0.000000
# SOComm_Not sure                                         0.000000
# SOComm_Yes, definitely                                  0.000000
# SOComm_Yes, somewhat                                    1.000000
# SOPartFreq_A few times per month or weekly              0.000000
# SOPartFreq_A few times per week                         0.000000
# SOPartFreq_Daily or almost daily                        0.000000
# SOPartFreq_I have never participated in Q&A on ...      1.000000
# SOPartFreq_Less than once per month or monthly          0.000000
# SOPartFreq_Multiple times per day                       0.000000
# SOVisitFreq_A few times per month or weekly             0.000000
# SOVisitFreq_A few times per week                        0.000000
# SOVisitFreq_Daily or almost daily                       0.000000
# SOVisitFreq_I have never visited Stack Overflow...      0.000000
# SOVisitFreq_Less than once per month or monthly         0.000000
# SOVisitFreq_Multiple times per day                      1.000000
# SurveyEase_Difficult                                    0.000000
# SurveyEase_Easy                                         1.000000
# SurveyEase_Neither easy nor difficult                   0.000000
# SurveyLength_Appropriate in length                      1.000000
# SurveyLength_Too long                                   0.000000
# SurveyLength_Too short                                  0.000000
# Trans_No                                                1.000000
# Trans_Yes                                               0.000000
# UndergradMajor_A business discipline (such as a...      0.000000
# UndergradMajor_A health science (such as nursin...      0.000000
# UndergradMajor_A humanities discipline (such as...      0.000000
# UndergradMajor_A natural science (such as biolo...      0.000000
# UndergradMajor_A social science (such as anthro...      0.000000
# UndergradMajor_Another engineering discipline (...      0.000000
# UndergradMajor_Computer science, computer engin...      1.000000
# UndergradMajor_Fine arts or performing arts (su...      0.000000
# UndergradMajor_I never declared a major                 0.000000
# UndergradMajor_Information systems, information...      0.000000
# UndergradMajor_Mathematics or statistics                0.000000
# UndergradMajor_Web development or web design            0.000000
# WelcomeChange_A lot less welcome now than last ...      0.000000
# WelcomeChange_A lot more welcome now than last ...      0.000000
# WelcomeChange_Just as welcome now as I felt las...      1.000000
# WelcomeChange_Not applicable - I did not use St...      0.000000
# WelcomeChange_Somewhat less welcome now than la...      0.000000
# WelcomeChange_Somewhat more welcome now than la...      0.000000

# %%
def prepare_data(data=data, exclude_columns=None, features_to_use=None, apply_x_col=None, columns_to_bin=None):

    
    if exclude_columns is not None and features_to_use is not None:
        raise Exception("exclude_columns and features_to_use cannot be used at the same time.")

    if exclude_columns is not None:
        data = data.drop(exclude_columns, axis=1)

    if features_to_use is not None:
        data = data[features_to_use + ["revenue"]]

    x = data.drop('ConvertedComp', axis=1)
    
    y = data['ConvertedComp']

    if apply_x_col is not None:
        x = x.apply(apply_x_col)
    

    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size = 0.25, random_state = 42)

    if columns_to_bin is not None:
        for column in columns_to_bin:
            if column not in x_train.columns: continue
            x_train.loc[:,column], bins_ = pd.qcut(x_train.loc[:,column], q=4,  retbins=True, duplicates="drop")
            x_test.loc[:,column] = pd.cut(x_test.loc[:,column], bins=bins_, )
            
            x_train = pd.get_dummies(x_train)
            x_test = pd.get_dummies(x_test)
    
    return x_train, x_test, y_train, y_test, data

# %%
def scale_data(x_train, x_test, scaler=StandardScaler):

    scaler = scaler()
    scaler.fit(x_train)

    x_train_scaled = scaler.transform(x_train)
    x_train_scaled = pd.DataFrame(x_train_scaled, index=x_train.index, columns=x_train.columns)

    x_test_scaled = scaler.transform(x_test)
    x_test_scaled = pd.DataFrame(x_test_scaled, index=x_test.index, columns=x_test.columns)

    x_train_scaled.fillna(x_train_scaled.mean(), inplace=True)
    x_test_scaled.fillna(x_test_scaled.mean(), inplace=True)

    return x_train_scaled, x_test_scaled

# %%
def evaluate_regression(y_true_train, y_pred_train, y_true_test, y_pred_test, model_name="", model=None, num_feat=""):   
    return pd.DataFrame.from_records([[
                                       metrics.mean_squared_error(y_true_train, y_pred_train),
                                       metrics.mean_absolute_error(y_true_train, y_pred_train),
                                       metrics.max_error(y_true_train, y_pred_train),
                                       metrics.r2_score(y_true_train, y_pred_train), 
                                      metrics.mean_squared_error(y_true_test, y_pred_test),
                                       metrics.mean_absolute_error(y_true_test, y_pred_test),
                                       metrics.max_error(y_true_test, y_pred_test),
                                       metrics.r2_score(y_true_test, y_pred_test),
                                       model,
                                       num_feat]],
                                     
                                     index=[model_name], 
                                     columns=['mean_squared_error_train', 'mean_absolute_error_train', 'max_error_train', "r2_score_train",
                                              'mean_squared_error_test', 'mean_absolute_error_test', 'max_error_test', "r2_score_test", "model_object", "num_feat"])

# %%
def run_models(x_train, x_test, y_train, y_test, feture_elimination_num_feat=None):
        results = pd.DataFrame()
        for model in [linear_model.LinearRegression(), 
                        linear_model.RidgeCV(),
                        linear_model.LassoCV(),
                        svm.LinearSVR(),
                        #svm.SVR(kernel="rbf",),
                        #svm.SVR(kernel="poly"),
                        tree.DecisionTreeRegressor(),
                        RandomForestRegressor()]:
                
                if feture_elimination_num_feat is not None :
                        try:
                                if feture_elimination_num_feat == "auto":
                                        feture_elimination_num_feat = np.linspace(5,len(x_train.columns),5, dtype=int)

                                for n_features_to_select in feture_elimination_num_feat:
                                        model_ = RFE(estimator=model, n_features_to_select=n_features_to_select)
                                        model_.fit(x_train, y_train)
                                        y_train_pred = model_.predict(x_train)
                                        y_test_pred = model_.predict(x_test)

                                        results = results.append(evaluate_regression(y_train, y_train_pred, y_test, y_test_pred,
                                                                model_name=type(model_).__name__, model=model_, num_feat=n_features_to_select))
                                return results
                        except Exception as e:
                            print(e)
                                
                        
               
                model.fit(x_train, y_train)
                
                y_train_pred = model.predict(x_train)
                y_test_pred = model.predict(x_test)

                results = results.append(evaluate_regression(y_train, y_train_pred, y_test, y_test_pred,
                                        model_name=type(model).__name__, model=model, num_feat=len(x_train.columns) ))
        return results

# %%
experiment_list = pd.DataFrame()

def run(exclude_columns=None, features_to_use=None, name="", apply_x_col=None, x_train_=None, y_train_=None, columns_to_bin=None, feture_elimination_num_feat=None):
    global experiment_list
    print(name)

    x_train, x_test, y_train, y_test, data = prepare_data(exclude_columns=exclude_columns, 
                                                        features_to_use=features_to_use, 
                                                        apply_x_col=apply_x_col,
                                                        columns_to_bin=columns_to_bin)

    if x_train_ is not None or y_train_ is not None:
        x_train, y_train = x_train_, y_train_

    x_train, x_test = scale_data(x_train, x_test, scaler=StandardScaler)

    results = run_models(x_train, x_test, y_train, y_test, feture_elimination_num_feat=feture_elimination_num_feat)

    print("Min mean_squared_error_test Test",results.sort_values("mean_squared_error_test").iloc[0]["mean_squared_error_test"])

    best_model = results.sort_values("mean_squared_error_test").reset_index().loc[[0], ["mean_squared_error_train", 
                                                                                        "mean_squared_error_test", 
                                                                                        "index",
                                                                                        "num_feat",
                                                                                        "model_object"]].rename({0:name, "index":"model_name"})
    if experiment_list is not None:
        experiment_list = experiment_list.append(best_model)

    return results.sort_values("mean_squared_error_test")

# %%
results = run(exclude_columns=None, name="Initial Run")
# Out:
# Initial Run
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-691f70870a48> in <module>
# ----> 1 results = run(exclude_columns=None, name="Initial Run")
#
# <ipython-input-26-046c07cccd9a> in run(exclude_columns, features_to_use, name, apply_x_col, x_train_, y_train_, columns_to_bin, feture_elimination_num_feat)
#      15     x_train, x_test = scale_data(x_train, x_test, scaler=StandardScaler)
#      16
# ---> 17     results = run_models(x_train, x_test, y_train, y_test, feture_elimination_num_feat=feture_elimination_num_feat)
#      18
#      19     print("Min mean_squared_error_test Test",results.sort_values("mean_squared_error_test").iloc[0]["mean_squared_error_test"])
#
# <ipython-input-25-c1377fe07ca4> in run_models(x_train, x_test, y_train, y_test, feture_elimination_num_feat)
#      29
#      30
# ---> 31                 model.fit(x_train, y_train)
#      32
#      33                 y_train_pred = model.predict(x_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     166                                                         indices=indices)
#     167
# --> 168         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     169     else:
#     170         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     373                                            min_impurity_split)
#     374
# --> 375         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     376
#     377         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
results

# %%
x_train, x_test, y_train, y_test, data = prepare_data()

# %%
x_train

# %%
# All Features
x_train.columns.to_list()

# %%
y_test.mean()

# %%
float(7.917081e+04)

# %%
results = run(exclude_columns=None, name="Initial Run",feture_elimination_num_feat="auto")
