# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
from keras import models
from keras import layers
from keras import optimizers
from keras import initializers
from numpy.random import seed
import tensorflow

seed(1907)
tensorflow.random.set_seed(2)

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))


opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])

train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
initializer = initializers.RandomNormal(mean=0., stddev=1.)
network = models.Sequential()
#network.add(layers.Dense(128, activation='relu', kernel_initializer='random_normal', input_shape=(28 * 28,)))
network.add(layers.Dense(128, activation='relu', kernel_initializer=initializer, input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
initializer = initializers.RandomUniform(minval=0., maxval=1.)
network = models.Sequential()
#network.add(layers.Dense(128, activation='relu', kernel_initializer='random_uniform', input_shape=(28 * 28,)))
network.add(layers.Dense(128, activation='relu', kernel_initializer=initializer, input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='zeros', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_normal', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='glorot_uniform', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='he_normal', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)



#initializer = tf.keras.initializers.HeNormal()

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='he_uniform', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)



#initializer = tf.keras.initializers.HeNormal()

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='he_normal', input_shape=(28 * 28,)))
network.add(layers.Dense(10, kernel_initializer='glorot_normal', activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)



#initializer = tf.keras.initializers.HeNormal()

# %%
network = models.Sequential()
network.add(layers.Dense(128, activation='relu', kernel_initializer='lecun_normal', input_shape=(28 * 28,)))
network.add(layers.Dense(10, kernel_initializer='lecun_normal', activation='softmax'))



opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
network.compile(optimizer=opt,
loss='categorical_crossentropy',
metrics=['accuracy'])


network.fit(train_images, train_labels, epochs=5, batch_size=128)

test_loss, test_acc = network.evaluate(test_images, test_labels)

print('test_acc:', test_acc)



#initializer = tf.keras.initializers.HeNormal()
